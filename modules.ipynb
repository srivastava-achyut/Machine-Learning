# %% [markdown]
# modules and packages

# %%
import math 
math.sqrt(16)
# Out:
# 4.0

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
print(sqrt(64))
print(pi)
# Out:
# 8.0
# 3.141592653589793
