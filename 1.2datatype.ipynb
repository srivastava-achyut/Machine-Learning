# %%
## integer example

age=35
print(type(age))
# Out:
# <class 'int'>

# %%
##floating point datatype 

width=5.11
print(type(width))
# Out:
# <class 'float'>

# %%
name="Achyut"
print(name)
print(type(name))
# Out:
# Achyut
# <class 'str'>

# %%
## boolean algebra

type(True)
type(False)
# Out:
# bool

# %%
is_true=True
print(type(is_true))
# Out:
# <class 'bool'>

# %%
## common errors

result="Achyut"+5
#this will show error
