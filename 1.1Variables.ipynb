# %% [markdown]
# a=100

# %%
##variables 

a=100
age=32
name="Achyut"

print("age",age)
print("name",name)
# Out:
# age 32
# name Achyut

# %%
##naming convention
## variable name should be descreptive
## variables names are case senstitive

#valid variable name
first_name="Achyut"
second_name="Srivastava"

print("Full Name is : ",first_name,second_name)
# Out:
# Full Name is :  Achyut Srivastava

# %%
#understanding variable type

## python is dynamically typed, typed means type of variable defined at run time

age=29 #during runtime it will know that it is integer type

height=6.3 #float
name="Achyut" #string

print(type(name))
print(type(height))
# Out:
# <class 'str'>
# <class 'float'>

# %%
# type checking and type conversion

age=25
print(type(age))

#type conversion

age_str=str(age) #this will convert age from integer into string

print(type(age_str))
print(age_str)
# Out:
# <class 'int'>
# <class 'str'>
# 25

# %%
## we cannot convert string into int

height=6.11
print(type(height))
heigh=int(height)
print(heigh)
# Out:
# <class 'float'>
# 6

# %%
#dynamic typping
## python allows the type of variable to change as the program executes
var=10 
print(var,type(var))

var="hello"
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>

# %%
# input

age=input("what is the age")
print(age)
type(age)
# Out:
# 52

# %%
## calculator

num1=float(input("Enter your first number"))
num2=float(input("enter your second number"))

sum=num1+num2
difference=num1-num2
multiply=num1*num2
divide=num1/num2

print(sum)
print(difference)
print(multiply)
print(divide)
# Out:
# 79.0
# 11.0
# 1530.0
# 1.3235294117647058
