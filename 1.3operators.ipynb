# %%
# Arithmetic Operator
# all calculator operation are arithmetic operartion
a=10
b=5
print(a+b)

#exponential opeartion

result=a**b
print(result)
# Out:
# 15
# 100000

# %% [markdown]
# Comparision Operator

# %%
#comparision operator

a=10
b=20
a==b #False 
print(a!=b)
print(a<=b)
a>=b
# Out:
# True
# True
# False

# %% [markdown]
# Logical Opearator

# %%
## And , Or, Not

X=True
y=True 

result=X and y
print(result)
# Out:
# True

# %%
X=True
not X  #False
# Out:
# False
